# %% [markdown]
# ## Index by company (pivot wider)

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/leetcode_problems_and_company.csv')
df = df.drop(['problem_link'], axis = 1)
df.pivot(columns=['problem_name'], values='num_occur', index='company_name')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_549780/3253269477.py in <module>
#       1 df = pd.read_csv('../data/leetcode_problems_and_company.csv')
#       2 df = df.drop(['problem_link'], axis = 1)
# ----> 3 df.pivot(columns=['problem_name'], values='num_occur', index='company_name')
#
# ~/anaconda3/envs/cs320/lib/python3.9/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# ~/anaconda3/envs/cs320/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...

# %%
len(set(df['problem_name']))
# Out:
# 462
